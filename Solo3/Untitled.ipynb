# %%
import pandas as pd
import numpy as np

# %%
raw_data = pd.read_csv(filepath_or_buffer='../Solo3/input_data/complete_cust_data.csv')
# Out:
# C:\Users\hw831\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (172,179,211,215,217,219,220) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_data.groupby('LEARNING_TEST').
# Out:
#                         ZIP        ZIP4   LTD_SALES  LTD_TRANSACTIONS  \
# LEARNING_TEST
# LEARNING       1.201522e+09  66103940.0  23724630.0             92056
# TEST           6.474971e+08  36081377.0  13328979.0             50909
#
#                YTD_SALES_2009  YTD_TRANSACTIONS_2009  ZIP9_Supercode  \
# LEARNING_TEST
# LEARNING              4421193                  16748  11968438834936
# TEST                  2492970                   9240   6441373048107
#
#                     DPBC  INC_SCS_AMT_V4  INC_WOUTSCS_AMT_4     ...      \
# LEARNING_TEST                                                   ...
# LEARNING       6928428.0         2746030            2748805     ...
# TEST           3703942.0         1472125            1479142     ...
#
#                RESPONSE7  RESPONSE8  RESPONSE9  RESPONSE10  RESPONSE11  \
# LEARNING_TEST
# LEARNING             945       1056        819         702         742
# TEST                 544        598        448         382         396
#
# ...

# %%
del raw_data['INC_WOUTSCS_AMT_4']

# %%
raw_data.index
# Out:
# RangeIndex(start=0, stop=30779, step=1, name='A')

# %%
df2 = raw_data.set_index('BUYER_STATUS')

# %%
df2.sum(level='BUYER_STATUS')
# Out:
#                       ZIP        ZIP4   LTD_SALES  LTD_TRANSACTIONS  \
# BUYER_STATUS
# ACTIVE        817160542.0  49036235.0  25119270.0             94180
# INACTIVE      550349739.0  27708623.0   5201553.0             20752
# LAPSED        481508721.0  25440459.0   6732786.0             28033
#
#               YTD_SALES_2009  YTD_TRANSACTIONS_2009  ZIP9_Supercode  \
# BUYER_STATUS
# ACTIVE               6914163                  25988   8136816343605
# INACTIVE                   0                      0   5475300366793
# LAPSED                     0                      0   4797695172645
#
#                    DPBC  INC_SCS_AMT_V4  FIPSSTCD     ...      RESPONSE7  \
# BUYER_STATUS                                          ...
# ACTIVE        4736632.0         1918414    231234     ...           1489
# INACTIVE      3074133.0         1237885    155737     ...              0
# LAPSED        2821605.0         1061856    136272     ...              0
#
# ...

# %%
df2.dropna()
# Out:
# Empty DataFrame
# ...
